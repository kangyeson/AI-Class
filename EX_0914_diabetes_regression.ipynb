# %% [markdown]
# <a href="https://colab.research.google.com/github/kangyeson/AI-Class/blob/main/EX_0914_diabetes_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/diabetes.csv")
prevX = df.drop("Outcome", axis=1)
X = prevX.drop("BMI", axis=1)
y = df["BMI"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
ly_preds = model.predict(X_test)

# %%
print('평균제곱근오차', mean_squared_error(ly_preds, y_test))
# Out:
# 평균제곱근오차 56.494100046202725

# %%
def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)

print('평균제곱근오차', mse_np(ly_preds, y_test))
# Out:
# 평균제곱근오차 56.494100046202725

# %%
def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2 for a, p in zip(actual, predicted))
    mean_square_error = sum_square_error / len(actual)
    return mean_square_error

print('평균제곱근오차', mse(ly_preds, y_test))
# Out:
# 평균제곱근오차 56.494100046202774

# %% [markdown]
# DecisionTree

# %%
from sklearn.tree import DecisionTreeRegressor

decision_model = DecisionTreeRegressor()
decision_model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

dy_preds = decision_model.predict(X_test)
print('평균제곱근오차', mean_squared_error(dy_preds, y_test))
# Out:
# 평균제곱근오차 74.69006493506491

# %% [markdown]
# RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor

random_model = RandomForestRegressor()
random_model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

ry_preds = random_model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ry_preds, y_test))
# Out:
# 평균제곱근오차 48.45154452597401

# %% [markdown]
# SVR

# %%
from sklearn.svm import SVR

svr_model = SVR(kernel='linear')
svr_model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

ry_preds = svr_model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ry_preds, y_test))
# Out:
# 평균제곱근오차 54.9767228628547
