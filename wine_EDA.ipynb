# %% [markdown]
# <a href="https://colab.research.google.com/github/kangyeson/AI-Class/blob/main/wine_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 구글 드라이브 마운트

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import files

sns.set_theme(style="whitegrid")

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/wine.csv")

df
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# ...

# %% [markdown]
# # 데이터 구조 확인

# %%
print("데이터 크기:", df.shape)

print("\n처음 5개 데이터")
display(df.head())

print("\n변수 이름")
print(df.columns.tolist())

print("\n자료형")
print(df.dtypes)

print("\n데이터 정보")
df.info()
# Out:
# 데이터 크기: (178, 14)
#
# 처음 5개 데이터
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735
# 변수 이름
# ...

# %% [markdown]
# # 결측치와 중복 데이터 확인

# %%
print("변수별 결측치 개수")
print(df.isnull().sum())

print("\n중복 행 개수")
print(df.duplicated().sum())
# Out:
# 변수별 결측치 개수
# Wine                    0
# Alcohol                 0
# Malic.acid              0
# Ash                     0
# Acl                     0
# Mg                      0
# Phenols                 0
# Flavanoids              0
# Nonflavanoid.phenols    0
# Proanth                 0
# Color.int               0
# Hue                     0
# OD                      0
# Proline                 0
# dtype: int64
#
# 중복 행 개수
# 0

# %% [markdown]
# # 분석 변수 지정

# %%
numeric_cols = [
    'Alcohol', 'Malic.acid', 'Ash', 'Acl', 'Mg',
    'Phenols', 'Flavanoids', 'Nonflavanoid.phenols',
    'Proanth', 'Color.int', 'Hue', 'OD', 'Proline'
]

target_col = 'Wine'

# %% [markdown]
# # 레이블 종류와 개수 확인

# %%
print("레이블 종류")
print(df[target_col].unique())

print("\n레이블별 개수")
print(df[target_col].value_counts())
# Out:
# 레이블 종류
# [1 2 3]
#
# 레이블별 개수
# Wine
# 2    71
# 1    59
# 3    48
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))

ax = sns.countplot(
    data=df,
    x=target_col
)

for container in ax.containers:
    ax.bar_label(container)

plt.title("Number of Samples by Wine")
plt.xlabel("Wine")
plt.ylabel("Count")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 기술통계량 확인

# %%
display(df[numeric_cols].describe().round(3))
# Out:
#        Alcohol  Malic.acid      Ash      Acl       Mg  Phenols  Flavanoids  \
# count  178.000     178.000  178.000  178.000  178.000  178.000     178.000
# mean    13.001       2.336    2.367   19.495   99.742    2.295       2.029
# std      0.812       1.117    0.274    3.340   14.282    0.626       0.999
# min     11.030       0.740    1.360   10.600   70.000    0.980       0.340
# 25%     12.362       1.602    2.210   17.200   88.000    1.742       1.205
# 50%     13.050       1.865    2.360   19.500   98.000    2.355       2.135
# 75%     13.678       3.082    2.558   21.500  107.000    2.800       2.875
# max     14.830       5.800    3.230   30.000  162.000    3.880       5.080
#
#        Nonflavanoid.phenols  Proanth  Color.int      Hue       OD   Proline
# count               178.000  178.000    178.000  178.000  178.000   178.000
# mean                  0.362    1.591      5.058    0.957    2.612   746.893
# ...

# %% [markdown]
# # 품종별 평균과 표준편차 확인
#
# 품종별 평균의 차이가 크고, 표준편차가 작은 상위 6개 항목
# 1. Flavanoids : 2.982 / 2.081 / 0.781
# 2. Color.int : 5.528 / 3.087 / 7.396
# 3. Proline : 1115.712 / 519.507 / 629.896
# 4. OD : 3.158 / 2.785 / 1.684
# 5. Phenols : 2.840 / 2.259 / 1.679
# 6. Hue : 1.062 / 1.056 / 0.683

# %%
print("품종별 평균")
display(
    df.groupby(target_col)[numeric_cols]
      .mean()
      .round(3)
)

print("품종별 표준편차")
display(
    df.groupby(target_col)[numeric_cols]
      .std()
      .round(3)
)
# Out:
# 품종별 평균
#       Alcohol  Malic.acid    Ash     Acl       Mg  Phenols  Flavanoids  \
# Wine
# 1      13.745       2.011  2.456  17.037  106.339    2.840       2.982
# 2      12.279       1.933  2.245  20.238   94.549    2.259       2.081
# 3      13.154       3.334  2.437  21.417   99.312    1.679       0.781
#
#       Nonflavanoid.phenols  Proanth  Color.int    Hue     OD   Proline
# Wine
# 1                    0.290    1.899      5.528  1.062  3.158  1115.712
# 2                    0.364    1.630      3.087  1.056  2.785   519.507
# 3                    0.448    1.154      7.396  0.683  1.684   629.896
# 품종별 표준편차
#       Alcohol  Malic.acid    Ash    Acl      Mg  Phenols  Flavanoids  \
# Wine
# 1       0.462       0.689  0.227  2.546  10.499    0.339       0.397
# 2       0.538       1.016  0.315  3.350  16.753    0.545       0.706
# 3       0.530       1.088  0.185  2.258  10.890    0.357       0.294
#
#       Nonflavanoid.phenols  Proanth  Color.int    Hue     OD  Proline
# Wine
# ...

# %% [markdown]
# # 각 변수의 전체 분포 확인
# 봉우리가 2~3개로, 품종별 분포가 따로 형성되고 있어 품종 구별이 가능한 변수 : OD
#
# Wine은 분포가 넓어 대부분의 그래프가 뭉개짐

# %%
for col in numeric_cols:

    plt.figure(figsize=(7, 4))

    sns.histplot(
        data=df,
        x=col,
        bins=20,
        kde=True
    )

    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 품종별 변수 분포 비교
# 세 색깔이 겹치지 않고 각자 따로 서 있어, 구별하기 좋은 변수 :
# Alcohol, Phenols, Flavanoids, Color.int, Hue, Proanth, Proline

# %%
for col in numeric_cols:

    plt.figure(figsize=(7, 4))

    sns.histplot(
        data=df,
        x=col,
        hue=target_col,
        kde=True,
        element="step",
        stat="density",
        common_norm=False
    )

    plt.title(f"{col} Distribution by Wine")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Box Plot

# %%
for col in numeric_cols:

    plt.figure(figsize=(7, 4))

    sns.boxplot(
        data=df,
        x=target_col,
        y=col
    )

    plt.title(f"{col} by Wine")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Violin Plot

# %%
for col in numeric_cols:

    plt.figure(figsize=(7, 4))

    sns.violinplot(
        data=df,
        x=target_col,
        y=col,
        inner="quartile"
    )

    plt.title(f"{col} Distribution by Wine")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Pair Plot
# 기술 통계, 분포 확인, 품종별 비교 과정에서 레이블 구별에 사용하기 적합한 것으로 도출된 변수들의 관계를 확인
#
# 'Flavanoids', 'Color.int', 'Proline', 'OD', 'Phenols', 'Hue', 'Alcohol', 'Proanth'

# %%
key_cols = ['Flavanoids', 'Color.int', 'Proline', 'OD', 'Phenols', 'Hue', 'Alcohol', 'Proanth']

sns.pairplot(
    df,
    vars=key_cols,
    hue=target_col,
    diag_kind="hist"
)
plt.show()

# %% [markdown]
# # 변수 간 상관관계 분석

# %%
corr = df[key_cols].corr()

display(corr.round(3))
# Out:
#             Flavanoids  Color.int  Proline     OD  Phenols    Hue  Alcohol  \
# Flavanoids       1.000     -0.172    0.494  0.787    0.865  0.543    0.237
# Color.int       -0.172      1.000    0.316 -0.429   -0.055 -0.522    0.546
# Proline          0.494      0.316    1.000  0.313    0.498  0.236    0.644
# OD               0.787     -0.429    0.313  1.000    0.700  0.565    0.072
# Phenols          0.865     -0.055    0.498  0.700    1.000  0.434    0.289
# Hue              0.543     -0.522    0.236  0.565    0.434  1.000   -0.072
# Alcohol          0.237      0.546    0.644  0.072    0.289 -0.072    1.000
# Proanth          0.653     -0.025    0.330  0.519    0.612  0.296    0.137
#
#             Proanth
# Flavanoids    0.653
# Color.int    -0.025
# Proline       0.330
# OD            0.519
# Phenols       0.612
# Hue           0.296
# Alcohol       0.137
# Proanth       1.000

# %% [markdown]
# # 상관관계 Heatmap
# 상관관계가 강한 조합
#
# Flavanoids <-> Phenols
#
# Flavanoids <-> OD
#
# Proline <-> Alcohol
#
# Phenols <-> OD

# %%
plt.figure(figsize=(7, 6))

sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    square=True
)

plt.title("Correlation Matrix")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 플라보노이드와 페놀 함량의 관계

# %%
plt.figure(figsize=(7, 5))

sns.scatterplot(
    data=df,
    x='Flavanoids',
    y='Phenols',
    hue=target_col,
    s=70
)

plt.title("Alcohol vs Proline")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 프롤린과 알코올의 관계

# %%
plt.figure(figsize=(7, 5))

sns.scatterplot(
    data=df,
    x='Alcohol',
    y='Proline',
    hue=target_col,
    s=70
)

plt.title("Alcohol vs Proline")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 페놀 함량과 단백질 농도의 관계

# %%
plt.figure(figsize=(7, 5))

sns.scatterplot(
    data=df,
    x='Phenols',
    y='OD',
    hue=target_col,
    s=70
)
plt.title("Phenols vs OD")

plt.tight_layout()
plt.show()

# %% [markdown]
# # IQR을 이용한 이상치 탐지

# %%
for col in numeric_cols:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[
        (df[col] < lower) |
        (df[col] > upper)
    ]

    print(
        f"{col:20s} : "
        f"{len(outliers)}개 "
        f"(Lower={lower:.2f}, Upper={upper:.2f})"
    )
# Out:
# Alcohol              : 0개 (Lower=10.39, Upper=15.65)
# Malic.acid           : 3개 (Lower=-0.62, Upper=5.30)
# Ash                  : 3개 (Lower=1.69, Upper=3.08)
# Acl                  : 4개 (Lower=10.75, Upper=27.95)
# Mg                   : 4개 (Lower=59.50, Upper=135.50)
# Phenols              : 0개 (Lower=0.16, Upper=4.39)
# Flavanoids           : 0개 (Lower=-1.30, Upper=5.38)
# Nonflavanoid.phenols : 0개 (Lower=0.02, Upper=0.69)
# Proanth              : 2개 (Lower=0.20, Upper=3.00)
# Color.int            : 4개 (Lower=-1.25, Upper=10.67)
# Hue                  : 1개 (Lower=0.28, Upper=1.63)
# OD                   : 0개 (Lower=0.09, Upper=5.02)
# Proline              : 0개 (Lower=-226.25, Upper=1711.75)

# %% [markdown]
# # 실제 이상치 데이터 확인
# Color.int의 이상치는 실제 Wine3의 특성이었으므로, 제거 대상 X

# %%
for col in numeric_cols:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[
        (df[col] < lower) |
        (df[col] > upper)
    ]

    if len(outliers) > 0:
        print(f"\n[{col} 이상치]")
        display(outliers[[col, target_col]])
# Out:
# [Malic.acid 이상치]
#      Malic.acid  Wine
# 123        5.80     2
# 137        5.51     3
# 173        5.65     3
# [Ash 이상치]
#       Ash  Wine
# 25   3.22     1
# 59   1.36     2
# 121  3.23     2
# [Acl 이상치]
#       Acl  Wine
# 59   10.6     2
# 73   30.0     2
# 121  28.5     2
# 127  28.5     2
# [Mg 이상치]
#      Mg  Wine
# 69  151     2
# 73  139     2
# 78  136     2
# 95  162     2
# [Proanth 이상치]
#      Proanth  Wine
# 95      3.28     2
# 110     3.58     2
# [Color.int 이상치]
#      Color.int  Wine
# 151      10.80     3
# 158      13.00     3
# 159      11.75     3
# 166      10.68     3
# [Hue 이상치]
#       Hue  Wine
# 115  1.71     2

# %% [markdown]
# # 품종별 평균값 비교

# %%
plot_cols = ['Flavanoids', 'Color.int', 'Phenols', 'OD', 'Hue']
mean_long = (
    df.groupby(target_col)[plot_cols]
      .mean()
      .reset_index()
      .melt(
          id_vars=target_col,
          var_name="Feature",
          value_name="Mean"
      )
)

plt.figure(figsize=(10, 5))

sns.barplot(
    data=mean_long,
    x="Feature",
    y="Mean",
    hue=target_col
)

plt.title("Mean Feature Values by Wine")
plt.xlabel("Feature")
plt.ylabel("Mean")

plt.xticks(rotation=20)

plt.tight_layout()
plt.show()
